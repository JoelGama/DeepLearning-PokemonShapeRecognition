# %% [markdown]
# # Pokemon Shape Recognition

# %%
#Imports
import sys
import os
from pathlib import Path
import tensorflow as tf
import keras, keras.layers as Layers, keras.backend as K
import numpy as np
from sklearn.model_selection import train_test_split
from skimage import transform
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Images
#
# Nesta fase as imagens são transformadas para aparecerem apenas as formas dos pokemons. Desta forma no final é possível comparar as formas para que sejam apresentadas as formas mais semelhantes.

# %%
dataset = []
addresses = []
for img_address in Path("data").glob("*.png"):
    addresses.append(img_address)
    img = plt.imread(img_address, format='png')
    img[:,:,0:3][img[:,:,3]==0] = 255
    img = img[:,:,0:3] / 255
    img = img[:,:,0:3] - 0.5 #normalizing
    img = transform.resize(img, (64, 64))
    dataset.append(img)
dataset = np.array(dataset)
print(dataset.shape)

# function to show an image with matplot lib
def show_image(x):
    plt.imshow(np.clip(x+0.5, 0, 1))
    
IMG_SIZE = dataset[0].shape
print("Image shape: {}".format(IMG_SIZE))
print("Image mean: {}".format(np.round(np.mean(dataset[0]))))
print("Image std: {}".format(np.std(dataset[0])))
for i in range(6):
    idx = np.random.randint(0,high=(len(dataset)),size=1)[0]
    print("{}:{}".format(i,addresses[idx]))
    plt.subplot(2,3,i+1)
    show_image(dataset[idx][:,:,:])
# Out:
# (938, 64, 64, 3)
# Image shape: (64, 64, 3)
# Image mean: -0.0
# Image std: 0.4295858144760132
# 0:data\187.png
# 1:data\678-male.png
# 2:data\532.png
# 3:data\50.png
# 4:data\443.png
# 5:data\133.png

# %% [markdown]
# ## Split training and test sets

# %%
X_train, X_test = train_test_split(dataset, test_size=0.1, random_state=42)

# %% [markdown]
# ## Autoencoder
#
# Utilizando o keras é feito um autoencoder de 8 camadas. 4 para encode e 4 para decode.

# %%
def simple_autoencoder(img_shape, code_size):

    encoder = keras.models.Sequential()
    encoder.add(Layers.InputLayer(img_shape))
    encoder.add(Layers.Flatten())
    encoder.add(Layers.Dense(2046, activation='elu'))
    encoder.add(Layers.Dense(1024, activation='elu'))
    encoder.add(Layers.Dense(512, activation='elu'))
    encoder.add(Layers.Dense(256, activation='elu'))
    # actual encoder
    encoder.add(Layers.Dense(code_size))

    decoder = keras.models.Sequential()
    decoder.add(Layers.InputLayer((code_size,)))
    decoder.add(Layers.Dense(256, activation='elu'))
    decoder.add(Layers.Dense(512, activation='elu'))
    decoder.add(Layers.Dense(1024, activation='elu'))  
    decoder.add(Layers.Dense(2046, activation='elu'))  
    # actual decoder
    decoder.add(Layers.Dense(np.prod(img_shape)))
    decoder.add(Layers.Reshape(img_shape))

    return encoder,decoder

# %% [markdown]
# ## Training
#
# São feitas 200 epocas nesta primeira parte

# %%
encoder,decoder = simple_autoencoder(IMG_SIZE, code_size=128)

input_l = Layers.Input(IMG_SIZE)
code = encoder(input_l)
reconstruction = decoder(code)

autoencoder = keras.models.Model(inputs=input_l, outputs=reconstruction)
autoencoder.compile(optimizer='adamax', loss='mse')

autoencoder.fit(x=X_train, y=X_train, epochs=200,
                validation_data=[X_test, X_test])
# Out:
# Epoch 1/200
# 27/27 [==============================] - 5s 199ms/step - loss: 0.1997 - val_loss: 0.0000e+00
# Epoch 2/200
# 27/27 [==============================] - 5s 199ms/step - loss: 0.1080 - val_loss: 0.0000e+00
# Epoch 3/200
# 27/27 [==============================] - 5s 203ms/step - loss: 0.0958 - val_loss: 0.0000e+00
# Epoch 4/200
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0895 - val_loss: 0.0000e+00
# Epoch 5/200
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0851 - val_loss: 0.0000e+00
# Epoch 6/200
# 27/27 [==============================] - 6s 204ms/step - loss: 0.0819 - val_loss: 0.0000e+00
# Epoch 7/200
# 27/27 [==============================] - 5s 197ms/step - loss: 0.0779 - val_loss: 0.0000e+00
# Epoch 8/200
# 27/27 [==============================] - 5s 189ms/step - loss: 0.0737 - val_loss: 0.0000e+00
# Epoch 9/200
# 27/27 [==============================] - 5s 189ms/step - loss: 0.0698 - val_loss: 0.0000e+00
# Epoch 10/200
# 27/27 [==============================] - 5s 194ms/step - loss: 0.0668 - val_loss: 0.0000e+00
# Epoch 11/200
# 27/27 [==============================] - 5s 197ms/step - loss: 0.0641 - val_loss: 0.0000e+00
# Epoch 12/200
# 27/27 [==============================] - 6s 208ms/step - loss: 0.0619 - val_loss: 0.0000e+00
# Epoch 13/200
# 27/27 [==============================] - 5s 194ms/step - loss: 0.0598 - val_loss: 0.0000e+00
# Epoch 14/200
# 27/27 [==============================] - 5s 195ms/step - loss: 0.0583 - val_loss: 0.0000e+00
# Epoch 15/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0566 - val_loss: 0.0000e+00
# Epoch 16/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0550 - val_loss: 0.0000e+00
# Epoch 17/200
# 27/27 [==============================] - 6s 210ms/step - loss: 0.0533 - val_loss: 0.0000e+00
# Epoch 18/200
# 27/27 [==============================] - 6s 206ms/step - loss: 0.0523 - val_loss: 0.0000e+00
# Epoch 19/200
# 27/27 [==============================] - 6s 208ms/step - loss: 0.0510 - val_loss: 0.0000e+00
# Epoch 20/200
# 27/27 [==============================] - 5s 200ms/step - loss: 0.0500 - val_loss: 0.0000e+00
# Epoch 21/200
# 27/27 [==============================] - 6s 206ms/step - loss: 0.0489 - val_loss: 0.0000e+00
# Epoch 22/200
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0479 - val_loss: 0.0000e+00
# Epoch 23/200
# 27/27 [==============================] - 6s 236ms/step - loss: 0.0470 - val_loss: 0.0000e+00
# Epoch 24/200
# 27/27 [==============================] - 6s 219ms/step - loss: 0.0459 - val_loss: 0.0000e+00
# Epoch 25/200
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0454 - val_loss: 0.0000e+00
# Epoch 26/200
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0443 - val_loss: 0.0000e+00
# Epoch 27/200
# 27/27 [==============================] - 6s 213ms/step - loss: 0.0437 - val_loss: 0.0000e+00
# Epoch 28/200
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0429 - val_loss: 0.0000e+00
# Epoch 29/200
# 27/27 [==============================] - 6s 210ms/step - loss: 0.0423 - val_loss: 0.0000e+00
# Epoch 30/200
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0415 - val_loss: 0.0000e+00
# Epoch 31/200
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0413 - val_loss: 0.0000e+00
# Epoch 32/200
# 27/27 [==============================] - 6s 211ms/step - loss: 0.0401 - val_loss: 0.0000e+00
# Epoch 33/200
# 27/27 [==============================] - 6s 209ms/step - loss: 0.0395 - val_loss: 0.0000e+00
# Epoch 34/200
# 27/27 [==============================] - 6s 210ms/step - loss: 0.0392 - val_loss: 0.0000e+00
# Epoch 35/200
# 27/27 [==============================] - 6s 213ms/step - loss: 0.0383 - val_loss: 0.0000e+00
# Epoch 36/200
# 27/27 [==============================] - 6s 210ms/step - loss: 0.0376 - val_loss: 0.0000e+00
# Epoch 37/200
# 27/27 [==============================] - 6s 208ms/step - loss: 0.0371 - val_loss: 0.0000e+00
# Epoch 38/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0366 - val_loss: 0.0000e+00
# Epoch 39/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0362 - val_loss: 0.0000e+00
# Epoch 40/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0357 - val_loss: 0.0000e+00
# Epoch 41/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0355 - val_loss: 0.0000e+00
# Epoch 42/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0349 - val_loss: 0.0000e+00
# Epoch 43/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0343 - val_loss: 0.0000e+00
# Epoch 44/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0338 - val_loss: 0.0000e+00
# Epoch 45/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0332 - val_loss: 0.0000e+00
# Epoch 46/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0325 - val_loss: 0.0000e+00
# Epoch 47/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0323 - val_loss: 0.0000e+00
# Epoch 48/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.0318 - val_loss: 0.0000e+00
# Epoch 49/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0312 - val_loss: 0.0000e+00
# Epoch 50/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0310 - val_loss: 0.0000e+00
# Epoch 51/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0301 - val_loss: 0.0000e+00
# Epoch 52/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0297 - val_loss: 0.0000e+00
# Epoch 53/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0292 - val_loss: 0.0000e+00
# Epoch 54/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0288 - val_loss: 0.0000e+00
# Epoch 55/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0285 - val_loss: 0.0000e+00
# Epoch 56/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0280 - val_loss: 0.0000e+00
# Epoch 57/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0277 - val_loss: 0.0000e+00
# Epoch 58/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0275 - val_loss: 0.0000e+00
# Epoch 59/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0266 - val_loss: 0.0000e+00
# Epoch 60/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0259 - val_loss: 0.0000e+00
# Epoch 61/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0254 - val_loss: 0.0000e+00
# Epoch 62/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0248 - val_loss: 0.0000e+00
# Epoch 63/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0244 - val_loss: 0.0000e+00
# Epoch 64/200
# 27/27 [==============================] - 5s 191ms/step - loss: 0.0239 - val_loss: 0.0000e+00
# Epoch 65/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0235 - val_loss: 0.0000e+00
# Epoch 66/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0232 - val_loss: 0.0000e+00
# Epoch 67/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0226 - val_loss: 0.0000e+00
# Epoch 68/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0223 - val_loss: 0.0000e+00
# Epoch 69/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0219 - val_loss: 0.0000e+00
# Epoch 70/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0212 - val_loss: 0.0000e+00
# Epoch 71/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0209 - val_loss: 0.0000e+00
# Epoch 72/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0203 - val_loss: 0.0000e+00
# Epoch 73/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0198 - val_loss: 0.0000e+00
# Epoch 74/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0195 - val_loss: 0.0000e+00
# Epoch 75/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0192 - val_loss: 0.0000e+00
# Epoch 76/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0187 - val_loss: 0.0000e+00
# Epoch 77/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0181 - val_loss: 0.0000e+00
# Epoch 78/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0174 - val_loss: 0.0000e+00
# Epoch 79/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0172 - val_loss: 0.0000e+00
# Epoch 80/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0169 - val_loss: 0.0000e+00
# Epoch 81/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0166 - val_loss: 0.0000e+00
# Epoch 82/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0164 - val_loss: 0.0000e+00
# Epoch 83/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0164 - val_loss: 0.0000e+00
# Epoch 84/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0159 - val_loss: 0.0000e+00
# Epoch 85/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0153 - val_loss: 0.0000e+00
# Epoch 86/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0148 - val_loss: 0.0000e+00
# Epoch 87/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0142 - val_loss: 0.0000e+00
# Epoch 88/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0142 - val_loss: 0.0000e+00
# Epoch 89/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0140 - val_loss: 0.0000e+00
# Epoch 90/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0136 - val_loss: 0.0000e+00
# Epoch 91/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0134 - val_loss: 0.0000e+00
# Epoch 92/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0128 - val_loss: 0.0000e+00
# Epoch 93/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0124 - val_loss: 0.0000e+00
# Epoch 94/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0127 - val_loss: 0.0000e+00
# Epoch 95/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0121 - val_loss: 0.0000e+00
# Epoch 96/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0119 - val_loss: 0.0000e+00
# Epoch 97/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.0114 - val_loss: 0.0000e+00
# Epoch 98/200
# 27/27 [==============================] - 5s 189ms/step - loss: 0.0110 - val_loss: 0.0000e+00
# Epoch 99/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0106 - val_loss: 0.0000e+00
# Epoch 100/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0102 - val_loss: 0.0000e+00
# Epoch 101/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0108 - val_loss: 0.0000e+00
# Epoch 102/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0107 - val_loss: 0.0000e+00
# Epoch 103/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0108 - val_loss: 0.0000e+00
# Epoch 104/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0101 - val_loss: 0.0000e+00
# Epoch 105/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0098 - val_loss: 0.0000e+00
# Epoch 106/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0094 - val_loss: 0.0000e+00
# Epoch 107/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0090 - val_loss: 0.0000e+00
# Epoch 108/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0087 - val_loss: 0.0000e+00
# Epoch 109/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0088 - val_loss: 0.0000e+00
# Epoch 110/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0088 - val_loss: 0.0000e+00
# Epoch 111/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0085 - val_loss: 0.0000e+00
# Epoch 112/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0087 - val_loss: 0.0000e+00
# Epoch 113/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0086 - val_loss: 0.0000e+00
# Epoch 114/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0081 - val_loss: 0.0000e+00
# Epoch 115/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0076 - val_loss: 0.0000e+00
# Epoch 116/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0075 - val_loss: 0.0000e+00
# Epoch 117/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0075 - val_loss: 0.0000e+00
# Epoch 118/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0079 - val_loss: 0.0000e+00
# Epoch 119/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0080 - val_loss: 0.0000e+00
# Epoch 120/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.0078 - val_loss: 0.0000e+00
# Epoch 121/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0076 - val_loss: 0.0000e+00
# Epoch 122/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0073 - val_loss: 0.0000e+00
# Epoch 123/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0070 - val_loss: 0.0000e+00
# Epoch 124/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0070 - val_loss: 0.0000e+00
# Epoch 125/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0069 - val_loss: 0.0000e+00
# Epoch 126/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0067 - val_loss: 0.0000e+00
# Epoch 127/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0066 - val_loss: 0.0000e+00
# Epoch 128/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0064 - val_loss: 0.0000e+00
# Epoch 129/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0065 - val_loss: 0.0000e+00
# Epoch 130/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0064 - val_loss: 0.0000e+00
# Epoch 131/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0065 - val_loss: 0.0000e+00
# Epoch 132/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0062 - val_loss: 0.0000e+00
# Epoch 133/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0067 - val_loss: 0.0000e+00
# Epoch 134/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0069 - val_loss: 0.0000e+00
# Epoch 135/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0065 - val_loss: 0.0000e+00
# Epoch 136/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0062 - val_loss: 0.0000e+00
# Epoch 137/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.0060 - val_loss: 0.0000e+00
# Epoch 138/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0063 - val_loss: 0.0000e+00
# Epoch 139/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0062 - val_loss: 0.0000e+00
# Epoch 140/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0062 - val_loss: 0.0000e+00
# Epoch 141/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0056 - val_loss: 0.0000e+00
# Epoch 142/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0052 - val_loss: 0.0000e+00
# Epoch 143/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0051 - val_loss: 0.0000e+00
# Epoch 144/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0053 - val_loss: 0.0000e+00
# Epoch 145/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0054 - val_loss: 0.0000e+00
# Epoch 146/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0054 - val_loss: 0.0000e+00
# Epoch 147/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0061 - val_loss: 0.0000e+00
# Epoch 148/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0060 - val_loss: 0.0000e+00
# Epoch 149/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0057 - val_loss: 0.0000e+00
# Epoch 150/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0057 - val_loss: 0.0000e+00
# Epoch 151/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0057 - val_loss: 0.0000e+00
# Epoch 152/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0058 - val_loss: 0.0000e+00
# Epoch 153/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0056 - val_loss: 0.0000e+00
# Epoch 154/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0057 - val_loss: 0.0000e+00
# Epoch 155/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0053 - val_loss: 0.0000e+00
# Epoch 156/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0050 - val_loss: 0.0000e+00
# Epoch 157/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0051 - val_loss: 0.0000e+00
# Epoch 158/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.0046 - val_loss: 0.0000e+00
# Epoch 159/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0043 - val_loss: 0.0000e+00
# Epoch 160/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0046 - val_loss: 0.0000e+00
# Epoch 161/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0052 - val_loss: 0.0000e+00
# Epoch 162/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0055 - val_loss: 0.0000e+00
# Epoch 163/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0052 - val_loss: 0.0000e+00
# Epoch 164/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0053 - val_loss: 0.0000e+00
# Epoch 165/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0052 - val_loss: 0.0000e+00
# Epoch 166/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0052 - val_loss: 0.0000e+00
# Epoch 167/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.0051 - val_loss: 0.0000e+00
# Epoch 168/200
# 27/27 [==============================] - 5s 188ms/step - loss: 0.0049 - val_loss: 0.0000e+00
# Epoch 169/200
# 27/27 [==============================] - 5s 196ms/step - loss: 0.0050 - val_loss: 0.0000e+00
# Epoch 170/200
# 27/27 [==============================] - 5s 191ms/step - loss: 0.0051 - val_loss: 0.0000e+00
# Epoch 171/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0053 - val_loss: 0.0000e+00
# Epoch 172/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0050 - val_loss: 0.0000e+00
# Epoch 173/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0045 - val_loss: 0.0000e+00
# Epoch 174/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0046 - val_loss: 0.0000e+00
# Epoch 175/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0047 - val_loss: 0.0000e+00
# Epoch 176/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0049 - val_loss: 0.0000e+00
# Epoch 177/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0052 - val_loss: 0.0000e+00
# Epoch 178/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0049 - val_loss: 0.0000e+00
# Epoch 179/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0052 - val_loss: 0.0000e+00
# Epoch 180/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0048 - val_loss: 0.0000e+00
# Epoch 181/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0048 - val_loss: 0.0000e+00
# Epoch 182/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0047 - val_loss: 0.0000e+00
# Epoch 183/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0046 - val_loss: 0.0000e+00
# Epoch 184/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0048 - val_loss: 0.0000e+00
# Epoch 185/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0048 - val_loss: 0.0000e+00
# Epoch 186/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0047 - val_loss: 0.0000e+00
# Epoch 187/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0046 - val_loss: 0.0000e+00
# Epoch 188/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0045 - val_loss: 0.0000e+00
# Epoch 189/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0044 - val_loss: 0.0000e+00
# Epoch 190/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0044 - val_loss: 0.0000e+00
# Epoch 191/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0045 - val_loss: 0.0000e+00
# Epoch 192/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0041 - val_loss: 0.0000e+00
# Epoch 193/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0041 - val_loss: 0.0000e+00
# Epoch 194/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.0042 - val_loss: 0.0000e+00
# Epoch 195/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0040 - val_loss: 0.0000e+00
# Epoch 196/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0043 - val_loss: 0.0000e+00
# Epoch 197/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0046 - val_loss: 0.0000e+00
# Epoch 198/200
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0048 - val_loss: 0.0000e+00
# Epoch 199/200
# 27/27 [==============================] - 5s 189ms/step - loss: 0.0049 - val_loss: 0.0000e+00
# Epoch 200/200
# 27/27 [==============================] - 5s 186ms/step - loss: 0.0050 - val_loss: 0.0000e+00

# %%
#Function to visualize the original, code and reconstruction images

def visualize(img,encoder,decoder):
    """Draws original, encoded and decoded images"""
    code = encoder.predict(img[None])[0]  # img[None] is the same as img[np.newaxis, :]
    reco = decoder.predict(code[None])[0]

    plt.subplot(1,3,1)
    plt.title("Original")
    show_image(img)

    plt.subplot(1,3,2)
    plt.title("Code")
    plt.imshow(code.reshape([code.shape[-1]//2,-1]))

    plt.subplot(1,3,3)
    plt.title("Reconstructed")
    show_image(reco)
    plt.show()

# %%
autoencoder.save('models/ff_autoencoder.hd5')
encoder.save('models/ff_encoder.hd5')
decoder.save('models/ff_decoder.hd5')
# Out:
# WARNING:tensorflow:From c:\users\joelg\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: models/ff_autoencoder.hd5\assets
# INFO:tensorflow:Assets written to: models/ff_encoder.hd5\assets
# INFO:tensorflow:Assets written to: models/ff_decoder.hd5\assets

# %%
autoencoder = keras.models.load_model("models/ff_autoencoder.hd5")
encoder = keras.models.load_model("models/ff_encoder.hd5")
decoder = keras.models.load_model("models/ff_decoder.hd5")
score = autoencoder.evaluate(X_test,X_test,verbose=0)
print("PCA MSE:", score)

for i in range(5):
    img = X_test[i]
    visualize(img,encoder,decoder)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# PCA MSE: 0.05963155999779701

# %% [markdown]
# ## Convolutional layers
#
# Para a parte do decodificador do modelo é utilizada a Convolução Transposta. Em vez de converter um patch da imagem num único número, esta operação converte um único número num patch. ESão empilhadas várias dessas camadas para reconstruir a imagem original.

# %%
def covolutional_autoencoder(img_shape, code_size):

    # encoder where we compress the image information into the code
    encoder = keras.models.Sequential()
    encoder.add(Layers.InputLayer(img_shape))
    encoder.add(Layers.Conv2D(64,(3,3),activation='elu', padding='same', input_shape=img_shape))
    encoder.add(Layers.Dropout(0.2))
    encoder.add(Layers.Conv2D(128,(3,3),activation='elu', padding='same'))
    encoder.add(Layers.Dropout(0.2))
    encoder.add(Layers.Flatten())
    encoder.add(Layers.Dense(256))
    encoder.add(Layers.Dropout(0.2))
    encoder.add(Layers.Dense(code_size))

    # decoder where we expand the code into the image
    decoder = keras.models.Sequential()
    decoder.add(Layers.InputLayer((code_size,)))
    decoder.add(Layers.Dense(code_size))
    decoder.add(Layers.Dense(64*64*128))
    encoder.add(Layers.Dropout(0.2))
    decoder.add(Layers.Reshape(target_shape=(64,64,128)))
    decoder.add(Layers.Conv2DTranspose(filters=128, kernel_size=(3, 3), activation='elu', padding='same'))
    encoder.add(Layers.Dropout(0.2))
    decoder.add(Layers.Conv2DTranspose(filters=3, kernel_size=(3, 3), activation='elu', padding='same'))


    return encoder, decoder

# %%
encoder,decoder = covolutional_autoencoder(IMG_SIZE, code_size=128)

input_l = Layers.Input(IMG_SIZE)
code = encoder(input_l)
reconstruction = decoder(code)

autoencoder = keras.models.Model(inputs=input_l, outputs=reconstruction)
autoencoder.compile(optimizer='adamax', loss='mse')

autoencoder.fit(x=X_train, y=X_train, epochs=100,
                validation_data=[X_test, X_test])
# Out:
# Epoch 1/100
# 27/27 [==============================] - 34s 1s/step - loss: 1.3341 - val_loss: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.2221 - val_loss: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.1513 - val_loss: 0.0000e+00
# Epoch 4/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.1286 - val_loss: 0.0000e+00
# Epoch 5/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.1171 - val_loss: 0.0000e+00
# Epoch 6/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.1088 - val_loss: 0.0000e+00
# Epoch 7/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.1033 - val_loss: 0.0000e+00
# Epoch 8/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0982 - val_loss: 0.0000e+00
# Epoch 9/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0950 - val_loss: 0.0000e+00
# Epoch 10/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0915 - val_loss: 0.0000e+00
# Epoch 11/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0879 - val_loss: 0.0000e+00
# Epoch 12/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0850 - val_loss: 0.0000e+00
# Epoch 13/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0830 - val_loss: 0.0000e+00
# Epoch 14/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0811 - val_loss: 0.0000e+00
# Epoch 15/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0793 - val_loss: 0.0000e+00
# Epoch 16/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0776 - val_loss: 0.0000e+00
# Epoch 17/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0762 - val_loss: 0.0000e+00
# Epoch 18/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0743 - val_loss: 0.0000e+00
# Epoch 19/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0736 - val_loss: 0.0000e+00
# Epoch 20/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0718 - val_loss: 0.0000e+00
# Epoch 21/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0711 - val_loss: 0.0000e+00
# Epoch 22/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0701 - val_loss: 0.0000e+00
# Epoch 23/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0697 - val_loss: 0.0000e+00
# Epoch 24/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0681 - val_loss: 0.0000e+00
# Epoch 25/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0673 - val_loss: 0.0000e+00
# Epoch 26/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0672 - val_loss: 0.0000e+00
# Epoch 27/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0660 - val_loss: 0.0000e+00
# Epoch 28/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0652 - val_loss: 0.0000e+00
# Epoch 29/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0649 - val_loss: 0.0000e+00
# Epoch 30/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0643 - val_loss: 0.0000e+00
# Epoch 31/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0632 - val_loss: 0.0000e+00
# Epoch 32/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0629 - val_loss: 0.0000e+00
# Epoch 33/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0626 - val_loss: 0.0000e+00
# Epoch 34/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0619 - val_loss: 0.0000e+00
# Epoch 35/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0612 - val_loss: 0.0000e+00
# Epoch 36/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0609 - val_loss: 0.0000e+00
# Epoch 37/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0602 - val_loss: 0.0000e+00
# Epoch 38/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0601 - val_loss: 0.0000e+00
# Epoch 39/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0594 - val_loss: 0.0000e+00
# Epoch 40/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0588 - val_loss: 0.0000e+00
# Epoch 41/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0586 - val_loss: 0.0000e+00
# Epoch 42/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0584 - val_loss: 0.0000e+00
# Epoch 43/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0585 - val_loss: 0.0000e+00
# Epoch 44/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0574 - val_loss: 0.0000e+00
# Epoch 45/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0567 - val_loss: 0.0000e+00
# Epoch 46/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0566 - val_loss: 0.0000e+00
# Epoch 47/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0566 - val_loss: 0.0000e+00
# Epoch 48/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0561 - val_loss: 0.0000e+00
# Epoch 49/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0558 - val_loss: 0.0000e+00
# Epoch 50/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0557 - val_loss: 0.0000e+00
# Epoch 51/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0558 - val_loss: 0.0000e+00
# Epoch 52/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0554 - val_loss: 0.0000e+00
# Epoch 53/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0545 - val_loss: 0.0000e+00
# Epoch 54/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0544 - val_loss: 0.0000e+00
# Epoch 55/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0546 - val_loss: 0.0000e+00
# Epoch 56/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0543 - val_loss: 0.0000e+00
# Epoch 57/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0539 - val_loss: 0.0000e+00
# Epoch 58/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0541 - val_loss: 0.0000e+00
# Epoch 59/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0538 - val_loss: 0.0000e+00
# Epoch 60/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0534 - val_loss: 0.0000e+00
# Epoch 61/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0534 - val_loss: 0.0000e+00
# Epoch 62/100
# 27/27 [==============================] - 39s 1s/step - loss: 0.0529 - val_loss: 0.0000e+00
# Epoch 63/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0532 - val_loss: 0.0000e+00
# Epoch 64/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0531 - val_loss: 0.0000e+00
# Epoch 65/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0527 - val_loss: 0.0000e+00
# Epoch 66/100
# 27/27 [==============================] - 41s 2s/step - loss: 0.0521 - val_loss: 0.0000e+00
# Epoch 67/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0520 - val_loss: 0.0000e+00
# Epoch 68/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0512 - val_loss: 0.0000e+00
# Epoch 69/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0521 - val_loss: 0.0000e+00
# Epoch 70/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0511 - val_loss: 0.0000e+00
# Epoch 71/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0510 - val_loss: 0.0000e+00
# Epoch 72/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0509 - val_loss: 0.0000e+00
# Epoch 73/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0505 - val_loss: 0.0000e+00
# Epoch 74/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0505 - val_loss: 0.0000e+00
# Epoch 75/100
# 27/27 [==============================] - 40s 1s/step - loss: 0.0502 - val_loss: 0.0000e+00
# Epoch 76/100
# 27/27 [==============================] - 39s 1s/step - loss: 0.0499 - val_loss: 0.0000e+00
# Epoch 77/100
# 27/27 [==============================] - 39s 1s/step - loss: 0.0493 - val_loss: 0.0000e+00
# Epoch 78/100
# 27/27 [==============================] - 39s 1s/step - loss: 0.0501 - val_loss: 0.0000e+00
# Epoch 79/100
# 27/27 [==============================] - 39s 1s/step - loss: 0.0498 - val_loss: 0.0000e+00
# Epoch 80/100
# 27/27 [==============================] - 39s 1s/step - loss: 0.0488 - val_loss: 0.0000e+00
# Epoch 81/100
# 27/27 [==============================] - 39s 1s/step - loss: 0.0482 - val_loss: 0.0000e+00
# Epoch 82/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0480 - val_loss: 0.0000e+00
# Epoch 83/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0474 - val_loss: 0.0000e+00
# Epoch 84/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0478 - val_loss: 0.0000e+00
# Epoch 85/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0473 - val_loss: 0.0000e+00
# Epoch 86/100
# 27/27 [==============================] - 35s 1s/step - loss: 0.0470 - val_loss: 0.0000e+00
# Epoch 87/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0464 - val_loss: 0.0000e+00
# Epoch 88/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0465 - val_loss: 0.0000e+00
# Epoch 89/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0466 - val_loss: 0.0000e+00
# Epoch 90/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0462 - val_loss: 0.0000e+00
# Epoch 91/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0451 - val_loss: 0.0000e+00
# Epoch 92/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0450 - val_loss: 0.0000e+00
# Epoch 93/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0452 - val_loss: 0.0000e+00
# Epoch 94/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0449 - val_loss: 0.0000e+00
# Epoch 95/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0450 - val_loss: 0.0000e+00
# Epoch 96/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0440 - val_loss: 0.0000e+00
# Epoch 97/100
# 27/27 [==============================] - 38s 1s/step - loss: 0.0447 - val_loss: 0.0000e+00
# Epoch 98/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0440 - val_loss: 0.0000e+00
# Epoch 99/100
# 27/27 [==============================] - 37s 1s/step - loss: 0.0435 - val_loss: 0.0000e+00
# Epoch 100/100
# 27/27 [==============================] - 36s 1s/step - loss: 0.0436 - val_loss: 0.0000e+00

# %%
autoencoder.save('models/cnn_autoencoder.hd5')
encoder.save('models/cnn_encoder.hd5')
decoder.save('models/cnn_decoder.hd5')
# Out:
# INFO:tensorflow:Assets written to: models/cnn_autoencoder.hd5\assets
# INFO:tensorflow:Assets written to: models/cnn_encoder.hd5\assets
# INFO:tensorflow:Assets written to: models/cnn_decoder.hd5\assets

# %%
autoencoder = keras.models.load_model("models/cnn_autoencoder.hd5")
encoder = keras.models.load_model("models/cnn_encoder.hd5")
decoder = keras.models.load_model("models/cnn_decoder.hd5")
score = autoencoder.evaluate(X_test,X_test,verbose=0)
print("PCA MSE:", score)

for i in range(5):
    idx = np.random.randint(0,high=(len(X_train)),size=1)[0]
    img = X_train[idx]
    visualize(img,encoder,decoder)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# PCA MSE: 0.044666968286037445

# %% [markdown]
# ## Pokemon Similar Shapes Search
#
#
# Para fazer o cluster facilmente, é utilizado o algoritmo NearestNeighbors do scikits-learn.

# %%
codes = encoder.predict(dataset)
from sklearn.neighbors.unsupervised import NearestNeighbors
nei_clf = NearestNeighbors(metric="euclidean")
nei_clf.fit(codes)
# Out:
# NearestNeighbors(metric='euclidean')

# %%
def get_similar(image, n_neighbors=5):
    assert image.ndim==3,"image must be [batch,height,width,3]"

    code = encoder.predict(image[None])

    (distances,),(idx,) = nei_clf.kneighbors(code,n_neighbors=n_neighbors)

    n_zero_distance = np.sum(distances<0.1)
    if(n_zero_distance > 0):
        (distances,),(idx,) = nei_clf.kneighbors(code,n_neighbors=(n_neighbors+n_zero_distance))
        distances = distances[n_zero_distance:]
        idx = idx[n_zero_distance:]

    return distances,dataset[idx]

# %%
def show_similar(image):

    distances,neighbors = get_similar(image,n_neighbors=11)

    plt.figure(figsize=[8,7])
    plt.subplot(2,6,1)
    show_image(image)
    plt.title("Original image")

    for i in range(11):
        plt.subplot(2,6,i+2)
        show_image(neighbors[i])
        plt.title("Dist=%.3f"%distances[i])
    plt.show()

# %%
show_similar(dataset[314])
