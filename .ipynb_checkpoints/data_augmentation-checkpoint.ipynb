# %% [markdown]
# ### References
#
# https://www.tensorflow.org/tutorials/load_data/images
#
# https://www.tensorflow.org/api_docs/python/tf/data/Dataset
#
# https://www.youtube.com/watch?v=yH1cF7GnoIo
#
# https://www.datacamp.com/community/tutorials/tensorflow-tutorial

# %%
import tensorflow as tf
from tensorflow import keras
import os
import numpy as np

import matplotlib.pyplot as plt
import pathlib
from PIL import Image
import IPython.display as display
# Out:
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Batch size
#
# Batch size is an important parameter when training a network. It can influence speed and generalization, not necessarily in the same direction. There is no golden rule for the batch size but 32 is a commom number to start with.
#
# See: https://machinelearningmastery.com/how-to-control-the-speed-and-stability-of-training-neural-networks-with-gradient-descent-batch-size/
#
# Try with different batch sizes.

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 32

# %% [markdown]
# ### Prepare to load images

# %%
data_dir = pathlib.Path('gtsrb/train_images/')
signs = list(data_dir.glob('00001/*'))
  
classNames = np.array(os.listdir(data_dir))
classNames
# Out:
# array(['00000', '00001', '00002', '00003', '00004', '00005', '00006',
#        '00007', '00008', '00009', '00010', '00011', '00012', '00013',
#        '00014', '00015', '00016', '00017', '00018', '00019', '00020',
#        '00021', '00022', '00023', '00024', '00025', '00026', '00027',
#        '00028', '00029', '00030', '00031', '00032', '00033', '00034',
#        '00035', '00036', '00037', '00038', '00039', '00040', '00041',
#        '00042'], dtype='<U5')

# %% [markdown]
# ### Auxiliary functions

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == classNames

def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [32,32])

def get_bytes_and_label(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# ### Loading images takes place in here

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

listset = tf.data.Dataset.list_files("gtsrb/train_images/*/*.png")
dataset = listset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)

# %% [markdown]
# ### Information about image shape and size of training set

# %%
for image, label in dataset.take(1):
  print("Image shape: ", image.numpy().shape)
  
dataset_length = [i for i,_ in enumerate(dataset)][-1] + 1
print("Total images in dataset: ",dataset_length)
# Out:
# Image shape:  (32, 32, 3)
# Total images in dataset:  39209

# %%
import random

#https://www.tensorflow.org/api_docs/python/tf/image
#https://www.tensorflow.org/addons/api_docs/python/tfa/image

#pip install tensorflow-addons
import tensorflow_addons as tfa

def process_image(image, label):
    
    image = tf.image.resize(image, (64,64))
    
    r = random.random() * 0.3 - 0.15
    image = tfa.image.rotate(image, r)
    
    rx = random.random() * 8 - 4
    ry = random.random() * 8 - 4
    image = tfa.image.translate(image, [rx, ry])
    
    delta = random.random() * 0.5
    lower_saturation = 0.9 + random.random() * 0.2
    upper_saturation = lower_saturation + random.random() * 0.2
    lower_value = 0.9 + random.random() * 0.3
    upper_value = lower_value + random.random() * 0.4
    image = tfa.image.random_hsv_in_yiq(image, delta, lower_saturation, upper_saturation, lower_value, upper_value)
    image = tf.image.resize(image, (32,32))
    #image = tf.clip_by_value(tf.image.adjust_brightness(image, -0.2),0,1)
    return image, label

# %% [markdown]
# ### Preparing dataset

# %%
dataset = dataset.cache()
dataset = dataset.shuffle(buffer_size = dataset_length)
dataset = dataset.prefetch(buffer_size=AUTOTUNE)
dataset = dataset.map(process_image)
dataset = dataset.batch(batch_size=BATCH_SIZE)
dataset = dataset.repeat()

# %% [markdown]
# ### Loading and preparing test dataset

# %%
testset = tf.data.Dataset.list_files("gtsrb/test_images/*/*.png")
testset = testset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)
testset = testset.batch(batch_size=BATCH_SIZE)

# %% [markdown]
# ### Show a batch of training images

# %%
def show_batch(image_batch, label_batch):
  columns = 6
  rows = BATCH_SIZE / columns + 1  
  plt.figure(figsize=(10, 2 * rows))
  for n in range(BATCH_SIZE):
      ax = plt.subplot(rows, columns, n+1)
      plt.imshow((image_batch[n]))
      plt.title(classNames[label_batch[n]==1][0])
      plt.axis('off')
        
        
image_batch, label_batch = next(iter(dataset))        
show_batch(image_batch, label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Build a simple network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras import metrics
from tensorflow.keras.optimizers import Adam

def cnn55D3L2FC(classCount, imgSize, channels):
    model = Sequential()
    
    model.add(Conv2D(64, (5, 5), padding='same',
                     input_shape=(imgSize, imgSize, channels),
                     activation='relu'))                     
    model.add(Conv2D(64, (5, 5), activation='relu') ) 
    model.add(MaxPooling2D(pool_size=(2, 2)))    
    model.add(Conv2D(64, (3, 3), activation='relu') )   
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Dense(classCount, activation='softmax'))

    
    opt = Adam(lr=0.001)
    model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=[ metrics.categorical_accuracy])
    return model

model = cnn55D3L2FC(43, 32, 3)

# %% [markdown]
# ### Draw a diagram of the network
#
# This requires installing some packages, namely graphviz

# %%
tf.keras.utils.plot_model(model, 'multi_input_and_output_model.png', show_shapes=True)
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %% [markdown]
# ### Display a table with model information
#
# When building a model kee an eye on the number of trainable parameters. Try to keep it below 10 million

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        4864
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        102464
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               295040
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 444,843
# Trainable params: 444,843
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Perform a random split to create a validation set
#
# Note that due to the way the GTSRB is build (using video sequences) this is not an ideal approach. Try to partition the set manually, selecting a few sequences for validation purposes. Load the training and validation sets independently.

# %%
train_size = int(0.8 * dataset_length)
val_size = int(0.2 * dataset_length)
#train_dataset = dataset.take(train_size)
#val_dataset = dataset.skip(val_size)

# %% [markdown]
# ### Train the network

# %%
#history = model.fit(dataset, steps_per_epoch = 0.8*dataset_length/BATCH_SIZE,
#          epochs=20, validation_data = val_dataset, validation_steps= 0.2*dataset_length/BATCH_SIZE)

history = model.fit(dataset, steps_per_epoch = dataset_length/BATCH_SIZE,
          epochs=20, validation_data = testset, validation_steps= 12630/BATCH_SIZE)
# Out:
# Train for 1225.28125 steps, validate for 394.6875 steps
# Epoch 1/20
# 1226/1225 [==============================] - 46s 38ms/step - loss: 0.7829 - categorical_accuracy: 0.7762 - val_loss: 0.4743 - val_categorical_accuracy: 0.8811
# Epoch 2/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.1096 - categorical_accuracy: 0.9687 - val_loss: 0.4224 - val_categorical_accuracy: 0.8887
# Epoch 3/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0705 - categorical_accuracy: 0.9783 - val_loss: 0.4433 - val_categorical_accuracy: 0.9110
# Epoch 4/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0533 - categorical_accuracy: 0.9844 - val_loss: 0.4466 - val_categorical_accuracy: 0.9139
# Epoch 5/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0398 - categorical_accuracy: 0.9879 - val_loss: 0.3199 - val_categorical_accuracy: 0.9354
# Epoch 6/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0384 - categorical_accuracy: 0.9884 - val_loss: 0.3587 - val_categorical_accuracy: 0.9309
# Epoch 7/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0313 - categorical_accuracy: 0.9908 - val_loss: 0.4299 - val_categorical_accuracy: 0.9108
# Epoch 8/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0303 - categorical_accuracy: 0.9913 - val_loss: 0.4897 - val_categorical_accuracy: 0.9269
# Epoch 9/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0234 - categorical_accuracy: 0.9931 - val_loss: 0.4972 - val_categorical_accuracy: 0.9229
# Epoch 10/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0237 - categorical_accuracy: 0.9930 - val_loss: 0.5078 - val_categorical_accuracy: 0.9196
# Epoch 11/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0236 - categorical_accuracy: 0.9931 - val_loss: 0.4597 - val_categorical_accuracy: 0.9330
# Epoch 12/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0236 - categorical_accuracy: 0.9939 - val_loss: 0.5673 - val_categorical_accuracy: 0.9316
# Epoch 13/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0207 - categorical_accuracy: 0.9941 - val_loss: 0.4327 - val_categorical_accuracy: 0.9302
# Epoch 14/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0219 - categorical_accuracy: 0.9942 - val_loss: 0.4532 - val_categorical_accuracy: 0.9340
# Epoch 15/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0244 - categorical_accuracy: 0.9940 - val_loss: 0.3775 - val_categorical_accuracy: 0.9373
# Epoch 16/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0132 - categorical_accuracy: 0.9962 - val_loss: 0.6145 - val_categorical_accuracy: 0.9196
# Epoch 17/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0213 - categorical_accuracy: 0.9942 - val_loss: 0.5260 - val_categorical_accuracy: 0.9296
# Epoch 18/20
# 1226/1225 [==============================] - 41s 33ms/step - loss: 0.0167 - categorical_accuracy: 0.9953 - val_loss: 0.4234 - val_categorical_accuracy: 0.9405
# Epoch 19/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0180 - categorical_accuracy: 0.9954 - val_loss: 0.4865 - val_categorical_accuracy: 0.9425
# Epoch 20/20
# 1226/1225 [==============================] - 40s 33ms/step - loss: 0.0189 - categorical_accuracy: 0.9951 - val_loss: 0.4912 - val_categorical_accuracy: 0.9382

# %% [markdown]
# ### Plot the training history

# %%
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %% [markdown]
# ### Evaluate the model on the test set
#
# This is the accuracy number that really matters

# %%
model.evaluate(testset)
# Out:
# 395/395 [==============================] - 5s 12ms/step - loss: 0.6454 - categorical_accuracy: 0.9561
# [0.6454424111144327, 0.956057]
